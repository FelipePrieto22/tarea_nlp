# %% [markdown]
# ### Desafio 2
#
# Geolocalizar eventos en noticias
#
# Utilizando técnicas de tratamiento automático del lenguaje, el objetivo del desafío es estructurar la información de una noticia de la manera siguiente:
#
# - event: principal evento descrito en la noticia
# - category: categoria temática del evento
# - address: dirección dónde occurió el evento en formato: calle número, comuna, país
# - latitud: latitud del evento
# - longitud: longitud del evento
#
# Resultado: El formato del archivo CSV output que entregar contiene las columnas siguientes: id_news, event, category, address, latitud, longitud

# %% [markdown]
# #### Librerias

# %%
import pandas as pd
import spacy
from geopy.geocoders import Nominatim
from transformers import pipeline
import re

# %% [markdown]
# #### Preparacion

# %%
# Cargar el dataset de entrenamiento
df = pd.read_csv('./train_data.csv')

# Muestra aleatoria de 1000 registros
df_train = df.sample(n=1000, random_state=42)

# Barajar el DataFrame
df_train = df_train.sample(frac=1).reset_index(drop=True)

def format_df(df):
    """Convertir la columna de fechas al formato deseado."""
    df['date'] = pd.to_datetime(df['date'], format='%b %d, %Y @ %H:%M:%S.%f')
    df['date'] = df['date'].dt.strftime('%Y-%m-%d')
    return df

df_train = format_df(df_train)

# %% [markdown]
# #### Procesamiento

# %%
# Cargar el modelo de lenguaje natural en español
nlp = spacy.load('es_core_news_sm')

# pipeline de pregunta-respuesta
qa_model = pipeline("question-answering", "timpal0l/mdeberta-v3-base-squad2")
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
def extract_info(row):
    """Extraer información relevante de la noticia."""
    # Procesar el texto con spaCy
    text = row['text']
    doc = nlp(text)
    
    # Definir la pregunta para el modelo de QA
    question_event = "¿De qué tipo de evento habla la noticia?"

    question_place = "¿Dónde ocurrió el evento?"

    
    
    # Obtener la respuesta utilizando el modelo de QA
    qa_response = qa_model(question=question_event, context=text)
    event = qa_response['answer']  # Extraer solo el texto de la respuesta
    
    # Inicializar variables para la categoría
    category = "Categoría simulada"  # Simular extracción de categoría

    # Inicializar una lista para las direcciones encontradas
    addresses = [ent.text for ent in doc.ents if ent.label_ == 'GPE']
    
    # Formatear la dirección
    address = ", ".join(addresses) if addresses else "no encontrada"
    
    # Mostrar la noticia procesada y sus elementos
    print("--------")
    print(text)
    print(f"Noticia ID: {row['id_news']}")
    print(f"Evento: {event}")
    print(f"Categoría: {category}")
    print(f"Dirección: {address}")
    print("--------")
    
    return event, category, address

# Aplicar la función a cada fila del DataFrame
df_train[['event', 'category', 'address']] = df_train.apply(extract_info, axis=1, result_type='expand')

# Geocodificar las direcciones para obtener latitud y longitud
geolocator = Nominatim(user_agent="geoapiExercises")

def geocode_address(address):
    """Geocodificar una dirección para obtener latitud y longitud."""
    if address and address != "no encontrada":
        try:
            location = geolocator.geocode(address)
            if location:
                return location.latitude, location.longitude
            else:
                return None, None
        except Exception as e:
            print(f"Error geocodificando {address}: {e}")
            return None, None
    return None, None  # Retornar None si no hay dirección válida

# Aplicar la geocodificación
df_train[['latitud', 'longitud']] = df_train['address'].apply(lambda x: pd.Series(geocode_address(x)))

# Seleccionar las columnas finales para el CSV de salida
output_df = df_train[['id_news', 'event', 'category', 'address', 'latitud', 'longitud']]

# Guardar el DataFrame de salida en un archivo CSV
output_df.to_csv('output.csv', index=False)
# Out:
# --------
# (CNN) – El Comité Ejecutivo de la Unión de Federaciones Europeas de Fútbol (UEFA) realizó una reunión extraordinaria este viernes “tras la grave escalada de la situación de seguridad en Europa” y anunció que París sustituiría a la ciudad rusa de San Petersburgo como sede de la final de la Champions League. El encuentro se jugará el 28 de mayo en el Stade de France, el estadio nacional de Francia, ubicado justo al norte de París en Saint-Denis. Lee también: Avanza el ataque ruso: Se reportan fuertes explosiones en Kiev, capital de Ucrania En la reunión, “el Comité Ejecutivo de la UEFA también decidió que los clubes y equipos nacionales rusos y ucranianos que compitan en competiciones de la UEFA deberán jugar sus partidos como local en sedes neutrales hasta nuevo aviso”. The 2021/22 UEFA Men’s Champions League final will move from Saint Petersburg to Stade de France in Saint-Denis. The game will be played as initially scheduled on Saturday 28 May at 21:00 CET. Full statement: ⬇️ — UEFA (@UEFA) February 25, 2022
# Noticia ID: 49,313,393
# Evento:  la final de la Champions League.
# Categoría: Categoría simulada
# Dirección: no encontrada
# --------
# --------
# El Ministerio de Salud (Minsal) entregó un nuevo reporte sobre la pandemia de COVID-19, en el que se informó de 11.091 nuevos y 5 fallecidos registrados en la última jornada, con una positividad nacional superior al 15%. Según el informe oficial, del total de infecciones 6.911 corresponden a personas sintomáticas y 1.439 son pacientes que no presentan síntomas. Además, se registraron 2.741 test PCR positivo que no fueron notificados. La cifra total de personas que han sido diagnosticadas con COVID-19 a la fecha alcanza a 4.331.416 pacientes. De ese total, 40.296 se encuentran en etapa activa. Los casos recuperados, en tanto, a la fecha llegan a 4.225.466 en nuestro país. En cuanto a los fallecidos, el reporte del Minsal informó que en las últimas 24 horas se registraron 5 muertes por causas asociadas al COVID-19, de las cuales 5 son casos confirmados y 0 son casos probables. El número total de muertos a causa de la pandemia asciende a 59.845 en el país hasta la fecha, entre los que se cuentan 48.248 confirmados y 11.597 sospechosos o probables. Asimismo, 171 personas se encuentran hospitalizadas en Unidades de Cuidados Intensivos (UCI), de las cuales 111 están con apoyo de ventilación mecánica. Con relación a la Red Integrada de Salud, el Minsal aseguró que existe una cifra total de 251 camas críticas disponibles a lo largo de todo el país. Respecto a la Red de Laboratorios y la capacidad diagnóstica, el reporte diario informó los resultados de 33.241 exámenes PCR, de los cuales 5.204 resultaron positivos. Además se informó la realización de 36.568 test de antígenos, de los cuales 5.887 resultaron positivos. Con estas cifras, a la fecha se ha alcanzado un total de 42.625.235 exámenes analizados a nivel nacional. Minsal informó además que la positividad durante las últimas 24 horas alcanza el 15,66% en todo el país, mientras que en la Región Metropolitana es de 11,64%.
# Noticia ID: 49,449,662
# Evento:  pandemia de COVID-19,
# Categoría: Categoría simulada
# Dirección: no encontrada
# --------
# --------
# Hace casi dos semanas, Angie Alvarado, la hija de Anita Alvarado, arribó a Chile desde Australia, país en el cual vive hace ya tres años, sorprendiendo a sus seguidores, quienes desconocían los motivos del vuelo de la mujer que actualmente tiene 32 años a su tierra natal. Durante este fin de semana se supieron las razones del viaje de Angie, las cuales tienen que ver con una repentina enfermedad que afecta a su progenitora. Anita, actualmente, está internada en una clínica capitalina y su familia ha pedido donantes de sangre para ella. Te puede interesarEn pijama y con lentes: El look de Angelina Jolie para viajar en avión con su hijo MaddoxA 23 años de personificar al icónico villano de "La Momia": Así luce hoy el actor Arnold VoslooA siete años de ser Esmeralda en "Papá a la Deriva": Así luce actualmente la actriz Li Fridman Te puede interesar En pijama y con lentes: El look de Angelina Jolie para viajar en avión con su hijo Maddox A 23 años de personificar al icónico villano de "La Momia": Así luce hoy el actor Arnold Vosloo A siete años de ser Esmeralda en "Papá a la Deriva": Así luce actualmente la actriz Li Fridman En una entrevista que dio a LUN, comentó que hace dos semanas estaba cenando con su novio en Australia, cuando recibió llamados de su madre. No los atendió en el momento, ya que le devolvería los mensajes tras terminar de comer. Sin embargo, recibió un mensaje por WhatsApp de uno de sus hermanos que le avisó que Anita tuvo que ser internada de urgencia. Tras leer lo anterior se asustó, se informó más sobre lo que aquejaba a Anita, y tomó un vuelo directo a Chile sin avisarle a nadie.  "(Anita) llegó a la clínica por un dolor de estómago (...) le dijeron que había una fuga de sangre que aún no resuelven. Después de una endoscopia y colonoscopia encontraron todo mal. Tiene unos quistes y debe sacarse el útero y los ovarios el martes (2 de agosto). Que le llegue la menstruación a mi mamá es de mucha gravedad por su anemia", explicó al citado medio. Asimismo, Anita también será sometida a una biopsia "porque le pillaron unas cositas en el estómago y en el intestino, además de úlcera", aseveró.  Angie contó, finalmente, cómo fue el momento en que entró a la pieza de la clínica y su madre la vio por primera vez tras estar distanciadas físicamente durante tres años. "Ella no lo podía creer cuando me vio, me confundió con una enfermera. No podía quedarme allá sabiendo que no estaba bien y que mis hermanos necesitaban una figura materna estos días", cerró. Todo sobre Famosos chilenos
# Noticia ID: 49,357,807
# Evento:  una repentina enfermedad
# Categoría: Categoría simulada
# Dirección: no encontrada
# --------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 35
#      32     return event, category, address
#      34 # Aplicar la función a cada fila del DataFrame
# ---> 35 df_train[['event', 'category', 'address']] = df_train.apply(extract_info, axis=1, result_type='expand')
#      37 # Geocodificar las direcciones para obtener latitud y longitud
#      38 geolocator = Nominatim(user_agent="geoapiExercises")
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[13], line 11, in extract_info(row)
#       8 question = "¿De qué tipo de evento habla la noticia?"
#      10 # Obtener la respuesta utilizando el modelo de QA
# ---> 11 qa_response = qa_model(question=question, context=text)
#      12 event = qa_response['answer']  # Extraer solo el texto de la respuesta
#      14 # Inicializar variables para la categoría
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/pipelines/question_answering.py:393, in QuestionAnsweringPipeline.__call__(self, *args, **kwargs)
#     391 examples = self._args_parser(*args, **kwargs)
#     392 if isinstance(examples, (list, tuple)) and len(examples) == 1:
# --> 393     return super().__call__(examples[0], **kwargs)
#     394 return super().__call__(examples, **kwargs)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/pipelines/base.py:1249, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1247     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1248 elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1249     return next(
#    1250         iter(
#    1251             self.get_iterator(
#    1252                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1253             )
#    1254         )
#    1255     )
#    1256 else:
#    1257     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/pipelines/pt_utils.py:269, in PipelinePackIterator.__next__(self)
#     266             return accumulator
#     268 while not is_last:
# --> 269     processed = self.infer(next(self.iterator), **self.params)
#     270     if self.loader_batch_size is not None:
#     271         if isinstance(processed, torch.Tensor):
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/pipelines/base.py:1164, in Pipeline.forward(self, model_inputs, **forward_params)
#    1162     with inference_context():
#    1163         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1164         model_outputs = self._forward(model_inputs, **forward_params)
#    1165         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1166 else:
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/pipelines/question_answering.py:520, in QuestionAnsweringPipeline._forward(self, inputs)
#     518 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     519     model_inputs["use_cache"] = False
# --> 520 output = self.model(**model_inputs)
#     521 if isinstance(output, dict):
#     522     return {"start": output["start_logits"], "end": output["end_logits"], "example": example, **inputs}
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:1483, in DebertaV2ForQuestionAnswering.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1471 r"""
#    1472 start_positions (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1473     Labels for position (index) of the start of the labelled span for computing the token classification loss.
#    (...)
#    1479     are not taken into account for computing the loss.
#    1480 """
#    1481 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1483 outputs = self.deberta(
#    1484     input_ids,
#    1485     attention_mask=attention_mask,
#    1486     token_type_ids=token_type_ids,
#    1487     position_ids=position_ids,
#    1488     inputs_embeds=inputs_embeds,
#    1489     output_attentions=output_attentions,
#    1490     output_hidden_states=output_hidden_states,
#    1491     return_dict=return_dict,
#    1492 )
#    1494 sequence_output = outputs[0]
#    1496 logits = self.qa_outputs(sequence_output)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:1063, in DebertaV2Model.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1053     token_type_ids = torch.zeros(input_shape, dtype=torch.long, device=device)
#    1055 embedding_output = self.embeddings(
#    1056     input_ids=input_ids,
#    1057     token_type_ids=token_type_ids,
#    (...)
#    1060     inputs_embeds=inputs_embeds,
#    1061 )
# -> 1063 encoder_outputs = self.encoder(
#    1064     embedding_output,
#    1065     attention_mask,
#    1066     output_hidden_states=True,
#    1067     output_attentions=output_attentions,
#    1068     return_dict=return_dict,
#    1069 )
#    1070 encoded_layers = encoder_outputs[1]
#    1072 if self.z_steps > 1:
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:507, in DebertaV2Encoder.forward(self, hidden_states, attention_mask, output_hidden_states, output_attentions, query_states, relative_pos, return_dict)
#     497     output_states = self._gradient_checkpointing_func(
#     498         layer_module.__call__,
#     499         next_kv,
#    (...)
#     504         output_attentions,
#     505     )
#     506 else:
# --> 507     output_states = layer_module(
#     508         next_kv,
#     509         attention_mask,
#     510         query_states=query_states,
#     511         relative_pos=relative_pos,
#     512         rel_embeddings=rel_embeddings,
#     513         output_attentions=output_attentions,
#     514     )
#     516 if output_attentions:
#     517     output_states, att_m = output_states
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:355, in DebertaV2Layer.forward(self, hidden_states, attention_mask, query_states, relative_pos, rel_embeddings, output_attentions)
#     346 def forward(
#     347     self,
#     348     hidden_states,
#    (...)
#     353     output_attentions=False,
#     354 ):
# --> 355     attention_output = self.attention(
#     356         hidden_states,
#     357         attention_mask,
#     358         output_attentions=output_attentions,
#     359         query_states=query_states,
#     360         relative_pos=relative_pos,
#     361         rel_embeddings=rel_embeddings,
#     362     )
#     363     if output_attentions:
#     364         attention_output, att_matrix = attention_output
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:286, in DebertaV2Attention.forward(self, hidden_states, attention_mask, output_attentions, query_states, relative_pos, rel_embeddings)
#     277 def forward(
#     278     self,
#     279     hidden_states,
#    (...)
#     284     rel_embeddings=None,
#     285 ):
# --> 286     self_output = self.self(
#     287         hidden_states,
#     288         attention_mask,
#     289         output_attentions,
#     290         query_states=query_states,
#     291         relative_pos=relative_pos,
#     292         rel_embeddings=rel_embeddings,
#     293     )
#     294     if output_attentions:
#     295         self_output, att_matrix = self_output
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:699, in DisentangledSelfAttention.forward(self, hidden_states, attention_mask, output_attentions, query_states, relative_pos, rel_embeddings)
#     697 if query_states is None:
#     698     query_states = hidden_states
# --> 699 query_layer = self.transpose_for_scores(self.query_proj(query_states), self.num_attention_heads)
#     700 key_layer = self.transpose_for_scores(self.key_proj(hidden_states), self.num_attention_heads)
#     701 value_layer = self.transpose_for_scores(self.value_proj(hidden_states), self.num_attention_heads)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/py_data/lib/python3.12/site-packages/torch/nn/modules/linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
